# %%
import pandas as pd

# %%
newschool = pd.read_csv('newschool.csv')

# %%
oldschool = pd.read_csv('oldschool.csv')

# %%
oldschool.head()
# Out:
#                        id                        name       artists  \
# 0  4xOTVtbCPcfxMs2hSt9D6i   Da Mystery of Chessboxin'  Wu-Tang Clan
# 1  119c93MHjrDLJTApCVGpvx                  C.R.E.A.M.  Wu-Tang Clan
# 2  2tNmhDlMbwQZLxQtWMt2EU                  Gravel Pit  Wu-Tang Clan
# 3  3glqlA5qY3bbo8UaUDGPnw  Triumph (feat. Cappadonna)  Wu-Tang Clan
# 4  1Sgj10byiGzPpI2IrXSFEn             Protect Ya Neck  Wu-Tang Clan
#
#    time_signature    tempo  valence  liveness  instrumentalness  acousticness  \
# 0               4  105.056    0.359     0.332          0.000000      0.334000
# 1               4  180.985    0.576     0.127          0.023900      0.570000
# 2               4  121.003    0.538     0.633          0.000000      0.222000
# 3               4   90.972    0.324     0.352          0.000028      0.000917
# 4               4  102.011    0.808     0.826          0.000007      0.032000
#
#    speechiness  mode  loudness  key  energy  danceability
# ...
